# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
from sst.sst import SingularSpectrumTransformation, sst_lanczos

# %% [markdown]
# # Data

# %%
url = "https://raw.githubusercontent.com/GrammarViz2/grammarviz2_src/master/data/stdb_308_0.txt"
df = pd.read_csv(url,header=None)

# %%
df.head()
# Out:
#        0
# 0 -0.078
# 1 -0.081
# 2 -0.088
# 3 -0.115
# 4 -0.159

# %%
df.iloc[:].plot(figsize=(20,5))

# %%
x = df.values[:,0]

# %%
Xh = np.random.rand(100,50)
Xt = np.random.rand(100,50)

# %%
sst_lanczos(Xt,Xh,6,3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-fe21bf1d3d78> in <module>()
# ----> 1 sst_lanczos(Xt,Xh,6,3)
#
# ~\Python Scripts\sst\sst\sst.py in sst_lanczos(X_test, X_history, rank, n_components)
#      63 def sst_lanczos(X_test,X_history,rank,n_components):
#      64     # calculate the first singular vec of test matrix
# ---> 65     u,_,_ = power_method(X_test,n_iter=2)
#      66     C = X_history @ X_history.T
#      67     T = lanczos(C,u,rank)
#
# ~\Python Scripts\sst\sst\util\linear_algebra.py in power_method(A, n_iter)
#      14
#      15     for i in range(n_iter):
# ---> 16         x0 = A.T @ A @ x0
#      17
#      18     v = x0 / norm(x0)
#
# ValueError: shapes (50,50) and (100,) not aligned: 50 (dim 1) != 100 (dim 0)
