# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
from sst.util.linear_algebra import power_method,power_method_py
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
A = np.random.rand(100,100)

# %%
def get_first(A,method):
    if method == "svd":
        return np.linalg.svd(A)[0][:,0]
    elif method == "pm_py":
        return power_method_py(A,2)[0]
    else:
        return power_method(A,2)[0]

# %%
# %timeit get_first(A,"svd")
# Out:
# 2.03 ms ± 56 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit get_first(A,"pm_py")
# Out:
# 117 µs ± 4.1 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit get_first(A,"pm")
# Out:
# 102 µs ± 13.9 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
u_svd = get_first(A,"svd")
u_pm = get_first(A,"pm")

# %%
# confirm accuracy
plt.plot(np.abs(u_svd),"o-")
plt.plot(np.abs(u_pm),"ro-")
